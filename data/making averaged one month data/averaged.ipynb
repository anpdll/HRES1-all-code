# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the CSV file
df = pd.read_csv('your_data.csv', parse_dates=['datetime'])

# Get a list of unique months
unique_months = df['datetime'].dt.strftime('%Y-%m').unique()

# Create a dataframe for each month
for i, month in enumerate(unique_months, start=1):
    month_df = df[df['datetime'].dt.strftime('%Y-%m') == month]
    globals()[f'df{i}'] = month_df
# Out:
#      Year  Month  Day  Hour  Minute  DNI  DHI  GHI  DewPoint  Temperature  \
# 0    2022      1    1     0      30    0    0    0      14.1         14.4
# 1    2022      1    1     1      30    0    0    0      14.2         14.6
# 2    2022      1    1     2      30    0    0    0      14.1         14.4
# 3    2022      1    1     3      30    0    0    0      13.4         13.4
# 4    2022      1    1     4      30    0    0    0      12.1         12.1
# ..    ...    ...  ...   ...     ...  ...  ...  ...       ...          ...
# 739  2022      1   31    19      30    0    0    0      -4.5         -2.2
# 740  2022      1   31    20      30    0    0    0      -4.6         -2.2
# 741  2022      1   31    21      30    0    0    0      -4.6         -1.9
# 742  2022      1   31    22      30    0    0    0      -4.5         -1.7
# 743  2022      1   31    23      30    0    0    0      -4.4         -1.8
#
#      Pressure  RelativeHumidity  WindDirection  WindSpeed  SurfaceAlbedo  \
# ...
